# %%
#from base_curve import BaseZeroCurve
from zero_curve import Interpolation2Pow
from zero_curve import InterpolationLinear

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
inter = Interpolation2Pow([1.,2.,3.,4.,5.,6.,7.], [3,3.5,4.2,3.8,4,4.4,4], 1)

# %%
y = []
for x in np.linspace(1.0001, 6.999, 100):
    y.append(inter(x))
plt.plot(y)

# %%
inter = InterpolationLinear([1.,2.,3.,4.,5.,6.,7.], [3,3.5,4.2,3.8,4,4.4,4])

# %%
y = []
for x in np.linspace(1.0001, 6.999, 100):
    y.append(inter(x))
plt.plot(y)
